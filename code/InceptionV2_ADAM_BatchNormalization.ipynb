# %% [markdown]
# ## Load Data Set

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from keras.datasets import cifar100
from keras.utils import to_categorical
import numpy as np
import cv2
import os
from keras import backend as K

# %%
(x_train, y_train_), (x_test, y_test_) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
y_train = to_categorical(y_train_)
y_test = to_categorical(y_test_)

# %% [markdown]
# ## Inception V2 model

# %%
import keras
import tensorflow as tf
from keras.models import Model
from keras.layers import Dense, Activation, Dropout, Flatten, Reshape
from keras.layers import Conv2D, Input
from keras.layers import MaxPooling2D, BatchNormalization
from keras.callbacks import EarlyStopping
from keras.layers.merge import concatenate
import os

# %%
input_shape = (32, 32, 3)
input = Input(shape=input_shape)

# %%
layer1_1 = Conv2D(64, (1, 1), activation='elu', padding='same')(input)
layer1_2 = Conv2D(96, (1, 1), activation='elu', padding='same')(input)
layer1_2 = Conv2D(128, (3, 3), activation='elu', padding='same')(layer1_2)
layer1_3 = Conv2D(16, (1, 1), activation='elu', padding='same')(input)
layer1_3 = Conv2D(32, (5, 5), activation='elu', padding='same')(layer1_3)
layer1_4 = MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same', data_format='channels_last')(input)
layer1_4 = Conv2D(32, (1, 1), activation='elu', padding='same')(layer1_4)
 
concat = concatenate([layer1_1, layer1_2, layer1_3, layer1_4])
concat = BatchNormalization()(concat)
concat = Activation('elu')(concat)

# %%
layer2_1 = Conv2D(64, (1, 1), activation='elu', padding='same')(concat)
layer2_2 = Conv2D(96, (1, 1), activation='elu', padding='same')(concat)
layer2_2 = Conv2D(128, (3, 3), activation='elu', padding='same')(layer2_2)
layer2_3 = Conv2D(16, (1, 1), activation='elu', padding='same')(concat)
layer2_3 = Conv2D(32, (5, 5), activation='elu', padding='same')(layer2_3)
layer2_4 = MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same', data_format='channels_last')(concat)
layer2_4 = Conv2D(32, (1, 1), activation='elu', padding='same')(layer2_4)

concat2 = concatenate([layer2_1, layer2_2, layer2_3, layer2_4])
concat2 = BatchNormalization()(concat2)
concat2 = Activation('elu')(concat2)

# %%
# layer3_1 = Conv2D(64, (1, 1), activation='elu', padding='same')(concat2)
# layer3_2 = Conv2D(96, (1, 1), activation='elu', padding='same')(concat2)
# layer3_2 = Conv2D(128, (3, 3), activation='elu', padding='same')(layer3_2)
# layer3_3 = Conv2D(16, (1, 1), activation='elu', padding='same')(concat2)
# layer3_3 = Conv2D(32, (5, 5), activation='elu', padding='same')(layer3_3)
# layer3_4 = MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same', data_format='channels_last')(concat2)
# layer3_4 = Conv2D(32, (1, 1), activation='elu', padding='same')(layer3_4)

# concat3 = concatenate([layer3_1, layer3_2, layer3_3, layer3_4])
# concat3 = BatchNormalization()(concat3)
# concat3 = Activation('elu')(concat3)

# %%
# layer4_1 = Conv2D(64, (1, 1), activation='elu', padding='same')(concat3)
# layer4_2 = Conv2D(96, (1, 1), activation='elu', padding='same')(concat3)
# layer4_2 = Conv2D(128, (3, 3), activation='elu', padding='same')(layer4_2)
# layer4_3 = Conv2D(16, (1, 1), activation='elu', padding='same')(concat3)
# layer4_3 = Conv2D(32, (5, 5), activation='elu', padding='same')(layer4_3)
# layer4_4 = MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same', data_format='channels_last')(concat3)
# layer4_4 = Conv2D(32, (1, 1), activation='elu', padding='same')(layer4_4)

# concat4 = concatenate([layer4_1, layer4_2, layer4_3, layer4_4])
# concat4 = BatchNormalization()(concat4)
# concat4 = Activation('elu')(concat4)

output = Conv2D(8, (3, 3), activation=tf.keras.layers.LeakyReLU(alpha=0.3), padding='same')(concat2)
output = MaxPooling2D(pool_size=(3, 3))(output)
output = Flatten()(output)                 
output = Dense(100, activation='softmax')(output) 

model = Model(inputs=input, outputs=output) 
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 96)   384         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   64          input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   256         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  110720      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   12832       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   128         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 256)  0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 256)  1024        concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 256)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 96)   24672       activation[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 16)   4112        activation[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 256)  0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   16448       activation[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 128)  110720      conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   12832       conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 32)   8224        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_6[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 256)  1024        concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 256)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 8)    18440       activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 10, 10, 8)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 800)          0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          80100       flatten[0][0]
# ==================================================================================================
# Total params: 401,980
# Trainable params: 400,956
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %%
opt = keras.optimizers.Adam(learning_rate=0.0001, clipnorm=5)
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=opt, metrics=["accuracy"])
callback = EarlyStopping(monitor='val_loss', patience=20)
history = model.fit(x_train, y_train, batch_size=128, epochs=200, verbose=1, validation_data=(x_test, y_test), callbacks=[callback])
model.save_weights(filepath=F"/content/gdrive/My Drive/Checkpoints/InceptionV2_ADAM_BatchNormalization.h5")
# Out:
# Epoch 1/200
#   2/391 [..............................] - ETA: 21s - loss: 5.9840 - accuracy: 0.0117   WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0412s vs `on_train_batch_end` time: 0.0661s). Check your callbacks.
# 391/391 [==============================] - 48s 123ms/step - loss: 4.1987 - accuracy: 0.0716 - val_loss: 4.1439 - val_accuracy: 0.0771
# Epoch 2/200
# 391/391 [==============================] - 48s 123ms/step - loss: 3.5862 - accuracy: 0.1655 - val_loss: 3.5357 - val_accuracy: 0.1701
# Epoch 3/200
# 391/391 [==============================] - 48s 123ms/step - loss: 3.3003 - accuracy: 0.2172 - val_loss: 3.3095 - val_accuracy: 0.2202
# Epoch 4/200
# 391/391 [==============================] - 48s 123ms/step - loss: 3.1154 - accuracy: 0.2527 - val_loss: 3.1847 - val_accuracy: 0.2432
# Epoch 5/200
# 391/391 [==============================] - 48s 123ms/step - loss: 2.9726 - accuracy: 0.2804 - val_loss: 3.0847 - val_accuracy: 0.2599
# Epoch 6/200
# 391/391 [==============================] - 48s 123ms/step - loss: 2.8573 - accuracy: 0.3023 - val_loss: 2.9723 - val_accuracy: 0.2879
# Epoch 7/200
# 391/391 [==============================] - 48s 122ms/step - loss: 2.7600 - accuracy: 0.3207 - val_loss: 2.8992 - val_accuracy: 0.2953
# Epoch 8/200
# 391/391 [==============================] - 48s 122ms/step - loss: 2.6776 - accuracy: 0.3394 - val_loss: 2.8882 - val_accuracy: 0.2998
# Epoch 9/200
# 391/391 [==============================] - 48s 122ms/step - loss: 2.6059 - accuracy: 0.3531 - val_loss: 2.8379 - val_accuracy: 0.3115
200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.7885 - accuracy: 0.5329 - val_loss: 2.5095 - val_accuracy: 0.3848
# Epoch 35/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.7714 - accuracy: 0.5371 - val_loss: 2.5227 - val_accuracy: 0.3819
# Epoch 36/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.7522 - accuracy: 0.5435 - val_loss: 2.5388 - val_accuracy: 0.3842
# Epoch 37/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.7298 - accuracy: 0.5473 - val_loss: 2.5416 - val_accuracy: 0.3869
# Epoch 38/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.7149 - accuracy: 0.5492 - val_loss: 2.5415 - val_accuracy: 0.3840
# Epoch 39/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.6934 - accuracy: 0.5555 - val_loss: 2.5452 - val_accuracy: 0.3837
# Epoch 40/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.6780 - accuracy: 0.5612 - val_loss: 2.5383 - val_accuracy: 0.3864
# Epoch 41/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.6577 - accuracy: 0.5652 - val_loss: 2.5296 - val_accuracy: 0.3859
# Epoch 42/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.6382 - accuracy: 0.5709 - val_loss: 2.6444 - val_accuracy: 0.3637
# Epoch 43/200
# 391/391 [==============================] - 48s 123ms/step - loss: 1.6188 - accuracy: 0.5754 - val_loss: 2.5517 - val_accuracy: 0.3836
# Epoch 44/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.6051 - accuracy: 0.5765 - val_loss: 2.5582 - val_accuracy: 0.3876
# Epoch 45/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.5863 - accuracy: 0.5819 - val_loss: 2.5888 - val_accuracy: 0.3822
# Epoch 46/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.5687 - accuracy: 0.5885 - val_loss: 2.5599 - val_accuracy: 0.3801
# Epoch 47/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.5508 - accuracy: 0.5916 - val_loss: 2.5845 - val_accuracy: 0.3867
# Epoch 48/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.5323 - accuracy: 0.5970 - val_loss: 2.6090 - val_accuracy: 0.3825
# Epoch 49/200
# 391/391 [==============================] - 48s 123ms/step - loss: 1.5141 - accuracy: 0.5997 - val_loss: 2.5696 - val_accuracy: 0.3865
# Epoch 50/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.4984 - accuracy: 0.6047 - val_loss: 2.6020 - val_accuracy: 0.3796
# Epoch 51/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.4809 - accuracy: 0.6105 - val_loss: 2.6178 - val_accuracy: 0.3919
# Epoch 52/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.4652 - accuracy: 0.6117 - val_loss: 2.6085 - val_accuracy: 0.3766
# Epoch 53/200
# 391/391 [==============================] - 48s 122ms/step - loss: 1.4518 - accuracy: 0.6159 - val_loss: 2.6283 - val_accuracy: 0.3843

# %%
model.save_weights(filepath=F"/content/gdrive/My Drive/Checkpoints/InceptionV2_ADAM_BatchNormalization.h5")

# %% [markdown]
# ## Test Metrics

# %%
import matplotlib.pyplot as plt

history_dict = history.history
print(history_dict.keys())
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred = model.predict(x_test).argmax(-1)
import sklearn.metrics as metrics
print(metrics.classification_report(y_test.argmax(axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.64       100
#            1       0.49      0.49      0.49       100
#            2       0.22      0.15      0.18       100
#            3       0.20      0.18      0.19       100
#            4       0.19      0.25      0.22       100
#            5       0.32      0.36      0.34       100
#            6       0.46      0.46      0.46       100
#            7       0.40      0.34      0.37       100
#            8       0.49      0.52      0.50       100
#            9       0.62      0.58      0.60       100
#           10       0.27      0.33      0.30       100
#           11       0.36      0.19      0.25       100
#           12       0.34      0.38      0.36       100
#           13       0.38      0.30      0.34       100
#           14       0.38      0.26      0.31       100
#           15       0.31      0.28      0.29       100
#           16       0.57      0.39      0.46       100
#           17       0.56      0.57      0.57       100
#           18       0.30      0.30      0.30       100
#           19       0.28      0.28      0.28       100
#           20       0.61      0.66      0.63       100
#           21       0.51      0.58      0.54       100
#           22       0.37      0.34      0.36       100
#           23       0.42      0.70      0.53       100
#           24       0.49      0.63      0.55       100
#           25       0.33      0.26      0.29       100
#           26       0.31      0.26      0.28       100
#           27       0.20      0.39      0.26       100
#           28       0.62      0.61      0.62       100
#           29       0.36      0.35      0.36       100
#           30       0.41      0.34      0.37       100
#           31       0.43      0.37      0.40       100
#           32       0.29      0.31      0.30       100
#           33       0.27      0.50      0.35       100
#           34       0.39      0.35      0.37       100
#           35       0.27      0.21      0.24       100
#           36       0.50      0.34      0.40       100
#           37       0.36      0.43      0.39       100
#           38       0.24      0.27      0.25       100
#           39       0.22      0.26      0.24       100
#           40       0.52      0.35      0.42       100
#           41       0.71      0.58      0.64       100
#           42       0.29      0.41      0.34       100
#           43       0.44      0.39      0.41       100
#           44       0.11      0.09      0.10       100
#           45       0.20      0.20      0.20       100
#           46       0.28      0.18      0.22       100
#           47       0.43      0.50      0.46       100
#           48       0.53      0.71      0.61       100
#           49       0.55      0.58      0.56       100
#           50       0.15      0.11      0.13       100
#           51       0.30      0.22      0.25       100
#           52       0.56      0.54      0.55       100
#           53       0.54      0.46      0.50       100
#           54       0.51      0.26      0.34       100
#           55       0.12      0.08      0.10       100
#           56       0.40      0.51      0.45       100
#           57       0.46      0.36      0.40       100
#           58       0.50      0.51      0.51       100
#           59       0.26      0.35      0.30       100
#           60       0.50      0.82      0.62       100
#           61       0.52      0.51      0.52       100
#           62       0.39      0.42      0.40       100
#           63       0.27      0.43      0.33       100
#           64       0.20      0.16      0.18       100
#           65       0.17      0.11      0.13       100
#           66       0.30      0.28      0.29       100
#           67       0.33      0.32      0.32       100
#           68       0.68      0.74      0.71       100
#           69       0.57      0.59      0.58       100
#           70       0.41      0.31      0.35       100
#           71       0.58      0.53      0.55       100
#           72       0.17      0.20      0.18       100
#           73       0.36      0.34      0.35       100
#           74       0.32      0.23      0.27       100
#           75       0.63      0.56      0.59       100
#           76       0.59      0.66      0.63       100
#           77       0.19      0.19      0.19       100
#           78       0.28      0.21      0.24       100
#           79       0.35      0.42      0.38       100
#           80       0.18      0.15      0.16       100
#           81       0.43      0.45      0.44       100
#           82       0.52      0.70      0.60       100
#           83       0.33      0.37      0.35       100
#           84       0.27      0.26      0.26       100
#           85       0.40      0.59      0.48       100
#           86       0.38      0.42      0.40       100
#           87       0.51      0.38      0.43       100
#           88       0.35      0.34      0.34       100
#           89       0.41      0.41      0.41       100
#           90       0.35      0.37      0.36       100
#           91       0.54      0.57      0.56       100
#           92       0.28      0.16      0.20       100
#           93       0.25      0.31      0.28       100
#           94       0.65      0.77      0.70       100
#           95       0.52      0.25      0.34       100
#           96       0.36      0.33      0.34       100
#           97       0.29      0.38      0.33       100
#           98       0.17      0.11      0.13       100
#           99       0.28      0.27      0.27       100
#
#     accuracy                           0.38     10000
#    macro avg       0.38      0.38      0.38     10000
# weighted avg       0.38      0.38      0.38     10000

# %%
# model.load_weights(filepath=F"/content/gdrive/My Drive/Checkpoints/InceptionV2_ADAM_BatchNormalization.h5")

model.load_weights("InceptionV2_ADAM_BatchNormalization.h5")

# %%
result = model.evaluate(batch_size=128, x=x_test, y=y_test)
dict(zip(model.metrics_names,result))
